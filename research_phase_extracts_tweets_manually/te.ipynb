# %%
import tweepy
from tweepy import OAuthHandler
import json
import datetime as dt
import time
import os
import sys
import sqlalchemy
import pandas as pd
from pandas import DataFrame
from sqlalchemy import *
from sqlalchemy import schema
from sqlalchemy.types import *
import sqlalchemy.schema

# %%
consumer_key = 'NOrVFOrKaGpOsD1LHjlDmD9lA'
consumer_secret = '8Lg3hdsmIbEn9Q1fLTiWbCqHD7vp2OSc21mvTGElnudCr5jM7p'
access_token = '49683260-3LQ6XoNAFi9R7MVaSGU1igwNxJkfxL6aFpUJfe7pG'
access_secret = 'zNXNyrewzVYC2kIqQ1GlGQoLIDHmTJtjXpMFZhwKGxYb8'
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
new_tweets = api.list_timeline('ChillinQuillen', "Apple", per_page = 99)
forma = [(a.created_at,
          a.text,
          a.retweet_count,
          a.favorite_count,
          a.id,
          a.user.name,
          a.user.screen_name,
          a.user.description,
          a.user.id,
          a.user.location,
          a.user.favourites_count,
          a.user.followers_count,
          a.user.friends_count,
          a.user.statuses_count,
          a.user.created_at,
          a.user.verified,
          a.user.time_zone,
          a.coordinates,
          a.in_reply_to_status_id,
          a.in_reply_to_user_id,
          a.in_reply_to_screen_name) if a.coordinates is None else (a.created_at,
          a.text,
          a.retweet_count,
          a.favorite_count,
          a.id,
          a.user.name,
          a.user.screen_name,
          a.user.description,
          a.user.id,
          a.user.location,
          a.user.favourites_count,
          a.user.followers_count,
          a.user.friends_count,
          a.user.statuses_count,
          a.user.created_at,
          a.user.verified,
          a.user.time_zone,
          str(a.coordinates['coordinates']),
          a.in_reply_to_status_id,
          a.in_reply_to_user_id,
          a.in_reply_to_screen_name) for a in new_tweets]

print(forma[0][4])
#print(new_tweets[0])
# Out:
# 916429244200312835

# %%
#TWEETS = []
#for member in tweepy.Cursor(api.list_timeline, 'ChillinQuillen', 'Apple').items():
#    TWEETS.append(member)
    
forma = [(a.created_at,
          a.text,
          a.retweet_count,
          a.favorite_count,
          a.id,
          a.user.name,
          a.user.screen_name,
          a.user.description,
          a.user.id,
          a.user.location,
          a.user.favourites_count,
          a.user.followers_count,
          a.user.friends_count,
          a.user.statuses_count,
          a.user.created_at,
          a.user.verified,
          a.user.time_zone,
          a.coordinates,
          a.in_reply_to_status_id,
          a.in_reply_to_user_id,
          a.in_reply_to_screen_name) if a.coordinates is None else (a.created_at,
          a.text,
          a.retweet_count,
          a.favorite_count,
          a.id,
          a.user.name,
          a.user.screen_name,
          a.user.description,
          a.user.id,
          a.user.location,
          a.user.favourites_count,
          a.user.followers_count,
          a.user.friends_count,
          a.user.statuses_count,
          a.user.created_at,
          a.user.verified,
          a.user.time_zone,
          str(a.coordinates['coordinates']),
          a.in_reply_to_status_id,
          a.in_reply_to_user_id,
          a.in_reply_to_screen_name) for a in new_tweets]

data = {'created_at': [],'text': [],
    'retweet_count': [], 'tweet_id':[],
    'user_favorites_count': [], 'tweet_location': [],
    'user_followers_count':[], 'user_time_zone':[],
    'user_id':[], 'user_name':[], 'in_reply_to_status_id':[],
    'in_reply_to_user_id':[], 'in_reply_to_screen_name':[],
    'screen_name':[], 'user_verified':[],
    'user_location':[], 'user_description':[],
    'user_statuses_count': [], 'user_created_at':[],
    'user_friends_count': [], 'favorite_count': []}

for t in forma:
    data['created_at'].append(t[0])
    data['text'].append(t[1])
    data['retweet_count'].append(t[2])
    data['favorite_count'].append(t[3])
    data['tweet_id'].append(t[4])
    data['user_name'].append(t[5])
    data['screen_name'].append(t[6])
    data['user_description'].append(t[7])
    data['user_id'].append(t[8])
    data['user_location'].append(t[9])
    data['user_favorites_count'].append(t[10])
    data['user_followers_count'].append(t[11])
    data['user_friends_count'].append(t[12])
    data['user_statuses_count'].append(t[13])
    data['user_created_at'].append(t[14])
    data['user_verified'].append(t[15])
    data['user_time_zone'].append(t[16])
    data['tweet_location'].append(t[17])
    data['in_reply_to_status_id'].append(t[18])
    data['in_reply_to_user_id'].append(t[19])
    data['in_reply_to_screen_name'].append(t[20])

df = pd.DataFrame(data)
df['created_at'] = pd.to_datetime(df['created_at'])
df['user_created_at'] = pd.to_datetime(df['user_created_at'])

RT = []
for t in data['text']:
    RT.append(t.split()[0]=='RT')
df['RT'] = RT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-18f53307cc07> in <module>()
#      43           a.in_reply_to_status_id,
#      44           a.in_reply_to_user_id,
# ---> 45           a.in_reply_to_screen_name) for a in new_tweets]
#      46
#      47 data = {'created_at': [],'text': [],
#
# NameError: name 'new_tweets' is not defined

# %%
engine = create_engine('mysql+pymysql://root:@localhost/sawi_tweets?charset=utf8mb4', encoding='utf8', echo = False)

# %%
df.head()
# Out:
#            created_at  favorite_count in_reply_to_screen_name  \
# 0 2017-10-06 21:35:12               2                    None
# 1 2017-10-06 21:25:43              14                    None
# 2 2017-10-06 21:24:57              42                    None
# 3 2017-10-06 21:22:08               0                    None
# 4 2017-10-06 21:17:39               9                    None
#
#    in_reply_to_status_id  in_reply_to_user_id  retweet_count      screen_name  \
# 0                    NaN                  NaN              1             CNET
# 1                    NaN                  NaN              7             CNET
# 2                    NaN                  NaN             10          9to5mac
# 3                    NaN                  NaN             64  stroughtonsmith
# 4                    NaN                  NaN              3     appleinsider
#
#                                                 text            tweet_id  \
# 0  iOS 11 brought new photo features, but what do...  916416576458579968
# 1  We're having a hard time letting go of AIM...e...  916414188469346309
# 2  Opinion: Apple needs to include a fast chargin...  916413996156284929
# 3  RT @nick_bayton: Necromunda is coming back. Do...  916413287172116480
# 4  .@Apple's head of #iCloud infrastructure leave...  916412158967238656
#
#   tweet_location  ...   user_favorites_count user_followers_count  \
# 0           None  ...                   1363              1513663
# 1           None  ...                   1363              1513663
# 2           None  ...                    348               494419
# 3           None  ...                  15737                58628
# 4           None  ...                   1241               437664
#
#    user_friends_count   user_id          user_location     user_name  \
# 0                 317  30261067          San Francisco          CNET
# 1                 317  30261067          San Francisco          CNET
# 2                  16  15944436  Cupertino, California     9to5Mac 
# 3                 983  15267898                Ireland     Steve T-S
# 4                  37  20542450  Cupertino, California  AppleInsider
#
#   user_statuses_count              user_time_zone  user_verified     RT
# 0              155226  Pacific Time (US & Canada)           True  False
# 1              155226  Pacific Time (US & Canada)           True  False
# 2               48251  Pacific Time (US & Canada)           True  False
# 3              134571                      Dublin           True   True
# 4               31621  Central Time (US & Canada)           True  False
#
# [5 rows x 22 columns]

# %%
df.to_sql('sawi_tweets_historical_test', engine, if_exists='append', dtype={'in_reply_to_status_id': sqlalchemy.types.Text, 'in_reply_to_user_id': sqlalchemy.types.Text})

# %%
new_tweets = api.list_timeline('ChillinQuillen', "Apple" ,since_id=str(916406059748745216),max_id=str(916429244200312835-1))
print(new_tweets)
# Out:
# [Status(author=User(notifications=False, profile_banner_url='https://pbs.twimg.com/profile_banners/10545/1499381920', following=False, description='Designer, software engineer, fun Dad. Not a pundit, I just play one on Twitter. America was already great. 53% politics, 47% tech geekery. Wait for the show.', time_zone='Eastern Time (US & Canada)', default_profile=False, utc_offset=-14400, _json={'screen_name': 'flyosity', 'url': None, 'followers_count': 29255, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/602900681050169345/IzexW5Sy_normal.jpg', 'profile_link_color': '0564AD', 'created_at': 'Thu Oct 26 06:18:10 +0000 2006', 'profile_sidebar_fill_color': 'FFFFFF', 'translator_type': 'none', 'description': 'Designer, software engineer, fun Dad. Not a pundit, I just play one on Twitter. America was already great. 53% politics, 47% tech geekery. Wait for the show.', 'time_zone': 'Eastern Time (US & Canada)', 'is_translation_enabled': False, 'contributors_enabled': False, 'notifications': False, 'listed_count': 2462, 'default_profile': False, 'utc_offset': -14400, 'following': False, 'id': 10545, 'favourites_count': 48831, 'friends_count': 972, 'lang': 'en', 'protected': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/602900681050169345/IzexW5Sy_normal.jpg', 'id_str': '10545', 'profile_text_color': '4B585E', 'profile_background_color': '34393D', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/540518316775727104/tUfzPN4o.jpeg', 'verified': True, 'follow_request_sent': False, 'geo_enabled': False, 'is_translator': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/540518316775727104/tUfzPN4o.jpeg', 'location': 'Raleigh, NC', 'profile_use_background_image': True, 'has_extended_profile': True, 'name': 'Spike ⛏ Rundle', 'profile_sidebar_border_color': 'FFFFFF', 'entities': {'description': {'urls': []}}, 'default_profile_image': False, 'statuses_count': 69716, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10545/1499381920'}, translator_type='none', id_str='10545', profile_text_color='4B585E', profile_background_image_url='http://pbs.twimg.com/profile_background_images/540518316775727104/tUfzPN4o.jpeg', is_translation_enabled=False, profile_link_color='0564AD', has_extended_profile=True, name='Spike ⛏ Rundle', profile_sidebar_fill_color='FFFFFF', entities={'description': {'urls': []}}, default_profile_image=False, statuses_count=69716, protected=False, screen_name='flyosity', url=None, followers_count=29255, created_at=datetime.datetime(2006, 10, 26, 6, 18, 10), profile_background_tile=False, contributors_enabled=False, listed_count=2462, id=10545, friends_count=972, lang='en', profile_background_color='34393D', profile_image_url_https='https://pbs.twimg.com/profile_images/602900681050169345/IzexW5Sy_normal.jpg', profile_image_url='http://pbs.twimg.com/profile_images/602900681050169345/IzexW5Sy_normal.jpg', verified=True, follow_request_sent=False, geo_enabled=False, is_translator=False, _api=<tweepy.api.API object at 0x7f487e6dae80>, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/540518316775727104/tUfzPN4o.jpeg', location='Raleigh, NC', profile_use_background_image=True, profile_sidebar_border_color='FFFFFF', favourites_count=48831), created_at=datetime.datetime(2017, 10, 6, 22, 23, 18), favorite_count=0, quoted_status_id=916416570460688385, is_quote_status=True, id_str='916428679533690881', _api=<tweepy.api.API object at 0x7f487e6dae80>, in_reply_to_user_id_str=None, contributors=None, truncated=False, user=User(notifications=False, profile_banner_url='https://pbs.twimg.com/profile_banners/10545/1499381920', following=False, description='Designer, software engineer, fun Dad. Not a pundit, I just play one on Twitter. America was already great. 53% politics, 47% tech geekery. Wait for the show.', time_zone='Eastern Time (US & Canada)', default_pr ...

# %%
df = pd.read_sql_table("sawi_tweets_R", con = engine)

# %%
dfs = df.drop_duplicates(subset = 'status_id', inplace=False)

# %%
dfs.count()
# Out:
# created_at                      198
# status_id                       198
# text                            198
# truncated                       198
# source                          198
# status_in_reply_to_status_id     14
# status_in_reply_to_user_id       14
# in_reply_to_screen_name          14
# contributors                      0
# is_quote_status                 198
# retweet_count                   198
# favorite_count                  198
# favorited                       198
# retweeted                       198
# possibly_sensitive              153
# lang                            198
# status_quoted_status_id          14
# dtype: int64

# %%
dfs.to_csv("dalsi_radky2.csv", float_format='{:f}'.format)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cf1eedb290cb> in <module>()
# ----> 1 dfs.to_csv("dalsi_radky2.csv", float_format='{:f}'.format)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in save(self)
#    1590                 self.writer = csv.writer(f, **writer_kwargs)
#    1591
# -> 1592             self._save()
#    1593
#    1594         finally:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _save(self)
#    1691                 break
#    1692
# -> 1693             self._save_chunk(start_i, end_i)
#    1694
#    1695     def _save_chunk(self, start_i, end_i):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _save_chunk(self, start_i, end_i)
#    1705                                   decimal=self.decimal,
#    1706                                   date_format=self.date_format,
# -> 1707                                   quoting=self.quoting)
#    1708
#    1709             for col_loc, col in zip(b.mgr_locs, d):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in to_native_types(self, slicer, na_rep, float_format, decimal, quoting, **kwargs)
#    1620                                         decimal=decimal, quoting=quoting,
#    1621                                         fixed_width=False)
# -> 1622         return formatter.get_result_as_array()
#    1623
#    1624     def should_store(self, value):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in get_result_as_array(self)
#    1892
#    1893         if self.formatter is not None:
# -> 1894             return np.array([self.formatter(x) for x in self.values])
#    1895
#    1896         if self.fixed_width:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1892
#    1893         if self.formatter is not None:
# -> 1894             return np.array([self.formatter(x) for x in self.values])
#    1895
#    1896         if self.fixed_width:
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__
